# %%
BASE = "../data/raw"
TRAIN = "train"
IMG = "img"
ANN = "ann"
META = "meta.json"
EXT = (".json", ".jpeg")

# %%
import os
from PIL import Image
import numpy as np

# %%
for file in os.listdir(os.path.join(BASE, TRAIN, IMG )):
    print(file)
# Out:
# BloodImage_00001.jpeg
# BloodImage_00003.jpeg
# BloodImage_00004.jpeg
# BloodImage_00005.jpeg
# BloodImage_00006.jpeg
# BloodImage_00008.jpeg
# BloodImage_00009.jpeg
# BloodImage_00010.jpeg
# BloodImage_00012.jpeg
# BloodImage_00013.jpeg
# BloodImage_00020.jpeg
# BloodImage_00022.jpeg
# BloodImage_00023.jpeg
# BloodImage_00024.jpeg
# BloodImage_00026.jpeg
# BloodImage_00032.jpeg
# BloodImage_00034.jpeg
# BloodImage_00036.jpeg
# BloodImage_00038.jpeg
# BloodImage_00039.jpeg
# BloodImage_00040.jpeg
# BloodImage_00042.jpeg
# BloodImage_00043.jpeg
# BloodImage_00044.jpeg
# BloodImage_00045.jpeg
# BloodImage_00046.jpeg
# BloodImage_00047.jpeg
# BloodImage_00048.jpeg
# BloodImage_00049.jpeg
# BloodImage_00050.jpeg
# BloodImage_00052.jpeg
# BloodImage_00054.jpeg
# BloodImage_00056.jpeg
# BloodImage_00059.jpeg
# BloodImage_00069.jpeg
# BloodImage_00070.jpeg
# BloodImage_00071.jpeg
# BloodImage_00076.jpeg
# BloodImage_00078.jpeg
# BloodImage_00079.jpeg
# BloodImage_00081.jpeg
# ...

# %%
file = "BloodImage_00001.jpeg"

# %%
Image.open(os.path.join(BASE, TRAIN, IMG, file )).convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
arr = np.array(Image.open(os.path.join(BASE, TRAIN, IMG, file )).convert('RGB'))
arr.shape
# Out:
# (480, 640, 3)

# %%
import json
with open(os.path.join(BASE, TRAIN, ANN, file + EXT[0]), "r") as f:
    data = json.load(f)
data
# Out:
# {'description': '',
#  'tags': [],
#  'size': {'height': 480, 'width': 640},
#  'objects': [{'id': 7789770,
#    'classId': 13303,
#    'description': '',
#    'geometryType': 'rectangle',
#    'labelerLogin': 'gr@datasetninja.com',
#    'createdAt': '2023-06-22T21:03:46.663Z',
#    'updatedAt': '2023-06-22T21:03:46.663Z',
#    'tags': [],
#    'classTitle': 'WBC',
#    'points': {'exterior': [[68, 315], [286, 479]], 'interior': []}},
#   {'id': 7789769,
#    'classId': 13302,
#    'description': '',
#    'geometryType': 'rectangle',
#    'labelerLogin': 'gr@datasetninja.com',
#    'createdAt': '2023-06-22T21:03:46.662Z',
#    'updatedAt': '2023-06-22T21:03:46.662Z',
#    'tags': [],
#    'classTitle': 'RBC',
#    'points': {'exterior': [[346, 361], [446, 454]], 'interior': []}},
#   {'id': 7789768,
#    'classId': 13302,
#    'description': '',
#    'geometryType': 'rectangle',
#    'labelerLogin': 'gr@datasetninja.com',
#    'createdAt': '2023-06-22T21:03:46.662Z',
# ...
